# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
dataTildes = [[6691,6066],[7336,6166], [8024,6356], [8859, 6570], [9368, 6766], [10028,7106] ]

dfTildes = pd.DataFrame(dataTildes, columns = ['Python', 'Sass'])

a = sns.lineplot(x="Python", y="Sass", data=dfTildes)

# %%
SeabornOdataTudo = [
    [11132, 87.73, 12.27,"Goodwork", "Atômico"],
    [9867,90.08, 9.92,"Statusfy", "Atômico"], 
    [287621, 87.96, 12.04, "Speedcube", "Atômico"],
    [2992, 100, 0, "Developmint", "Atômico"],
    [1275, 94.35, 5.65, "Litcher", "Atômico"],
    [115097, 70.79, 29.21, "Gitlab", "Tradicional"],
    [3071, 22.08, 77.92, "Casper", "Tradicional"],
    [8749, 29.99, 70.01, "Electronjs.org", "Tradicional"],
    [17655, 58.31, 41.69, "Tildes", "Tradicional"],
    [2673, 77.52, 22.48, "Tusk", "Tradicional"]
]

dfTudo = pd.DataFrame(dataTudo, columns = [
                            "Total de linhas do projeto", 
                            "Porcentagem de linhas de código de programação", 
                            "Porcentagem de linhas de estilo",
                            "Nome do Projeto",
                            "Metodologia"])

b = sns.scatterplot(
    x="Total de linhas do projeto",
    y="Porcentagem de linhas de estilo",
    size="Total de linhas do projeto",
    sizes=(60, 600),
    alpha=0.5,
    hue="Metodologia",
    data=dfTudo
)
b.set_ylim(-1,101)
b.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
c = sns.barplot(x="Porcentagem de linhas de estilo", y="Nome do Projeto", hue="Metodologia",estimator=np.median, data=dfTudo)

# %%
t=sns.barplot(y="Nome do Projeto", x="Total de linhas do projeto", hue="Metodologia", data=dfTudo)
t.set_xscale("log")

# %%
dataSeries = [
    [10.70, 21.26, 30.90, 24.05, 16.00, 12.27],
    [00.46, 04.55, 09.01, 07.27, 09.78, 09.92],
    [11.79, 09.77, 12.50, 12.38, 12.16, 12.04],
    [06.78, 06.68, 06.61, 04.91, 05.03, 00.00],
    [47.30, 30.71, 25.49, 28.48, 23.10, 05.65],
]


# dataSeries2 = [
#     ["Serie1", 1, 10.70],
#     ["Serie1", 2, 21.26],
#     ["Serie1", 3, 30.90],
#     ["Serie1", 4, 24.05],
#     ["Serie1", 5, 16.00],
#     ["Serie1", 6, 12.27],
#     ["Serie2", 1 ,00.46],
#     ["Serie2", 2, 04.55],
#     ["Serie2", 3, 09.01],
#     ["Serie2", 4, 07.27],
#     ["Serie2", 5, 09.78],
#     ["Serie2", 6, 09.92],
#     ["Serie3", 1, 11.79],
#     ["Serie3", 2, 09.77],
#     ["Serie3", 3, 12.50],
#     ["Serie3", 4, 12.38],
#     ["Serie3", 5, 12.16],
#     ["Serie3", 6, 12.04],
#     ["Serie4", 1, 06.78],
#     ["Serie4", 2, 06.68],
#     ["Serie4", 3, 06.61],
#     ["Serie4", 4, 04.91],
#     ["Serie4", 5, 05.03],
#     ["Serie4", 6, 00.00],
#     ["Serie5", 1, 47.30],
#     ["Serie5", 2, 30.71],
#     ["Serie5", 3, 25.49],
#     ["Serie5", 4, 28.48],
#     ["Serie5", 5, 23.10],
#     ["Serie5", 6, 05.65],
# ]

dataSeries2 = [
    ["Atômico", 1, 10.70],
    ["Atômico", 2, 21.26],
    ["Atômico", 3, 30.90],
    ["Atômico", 4, 24.05],
    ["Atômico", 5, 16.00],
    ["Atômico", 6, 12.27],
    ["Atômico", 1 ,00.46],
    ["Atômico", 2, 04.55],
    ["Atômico", 3, 09.01],
    ["Atômico", 4, 07.27],
    ["Atômico", 5, 09.78],
    ["Atômico", 6, 09.92],
    ["Atômico", 1, 11.79],
    ["Atômico", 2, 09.77],
    ["Atômico", 3, 12.50],
    ["Atômico", 4, 12.38],
    ["Atômico", 5, 12.16],
    ["Atômico", 6, 12.04],
    ["Atômico", 1, 06.78],
    ["Atômico", 2, 06.68],
    ["Atômico", 3, 06.61],
    ["Atômico", 4, 04.91],
    ["Atômico", 5, 05.03],
    ["Atômico", 6, 00.00],
    ["Atômico", 1, 47.30],
    ["Atômico", 2, 30.71],
    ["Atômico", 3, 25.49],
    ["Atômico", 4, 28.48],
    ["Atômico", 5, 23.10],
    ["Atômico", 6, 05.65],
    ["Tradicional", 1, 34.73],
    ["Tradicional", 2, 24.41],
    ["Tradicional", 3, 29.09],
    ["Tradicional", 4, 32.17],
    ["Tradicional", 5, 31.06],
    ["Tradicional", 6, 29.21],
    ["Tradicional", 1, 94.84],
    ["Tradicional", 2, 90.29],
    ["Tradicional", 3, 86.03],
    ["Tradicional", 4, 89.37],
    ["Tradicional", 5, 79.73],
    ["Tradicional", 6, 77.92],
    ["Tradicional", 1, 77.80],
    ["Tradicional", 2, 92.01],
    ["Tradicional", 3, 90.96],
    ["Tradicional", 4, 93.26],
    ["Tradicional", 5, 78.70],
    ["Tradicional", 6, 70.01],
    ["Tradicional", 1, 47.55],
    ["Tradicional", 2, 45.67],
    ["Tradicional", 3, 44.20],
    ["Tradicional", 4, 42.58],
    ["Tradicional", 5, 41.94],
    ["Tradicional", 6, 41.69],
    ["Tradicional", 1, 01.20],
    ["Tradicional", 2, 17.72],
    ["Tradicional", 3, 33.33],
    ["Tradicional", 4, 38.82],
    ["Tradicional", 5, 33.30],
    ["Tradicional", 6, 22.48],
]

dfSeries = pd.DataFrame(dataSeries2, columns = ["Metodologia", "Número do commit", "Porcentagem de estilo"])

d = sns.lineplot(x="Número do commit", y="Porcentagem de estilo", hue="Metodologia" ,data=dfSeries)

d.set_ylim(0,100)
d.set_xlim(1,6)
# Out:
# (1, 6)

# %%
dataLocArquivo = [
    [81475, 1862, 33622, 151, "Tradicional"],
    [2624, 71, 6125, 79, "Tradicional"],
    [10294, 200, 7361, 118, "Tradicional"],
    [2072, 30, 601, 4, "Tradicional"],
    [9444, 174, 2292, 25, "Tradicional"],
    [9766, 409, 1366, 6, "Atômico"],
    [8888, 196, 979, 14, "Atômico"],
    [253000, 1026, 34621, 190, "Atômico"],
    [2992, 31, 0, 0, "Atômico"],
    [1203, 16, 72, 4, "Atômico"]
]

dfLocArquivo = pd.DataFrame(dataLocArquivo, columns = 
                            ["Linhas de código de programação", 
                             "Arquivos de código de programação",
                             "Linhas de estilo", 
                             "Arquivos de estilo", 
                             "Metodologia"])


dfLocArquivo["Linhas de código de programação por arquivo"] = dfLocArquivo["Linhas de código de programação"] / dfLocArquivo["Arquivos de código de programação"]
dfLocArquivo["Linhas de código de estilo por arquivo"] = dfLocArquivo["Linhas de estilo"] / dfLocArquivo["Arquivos de estilo"]

dfLocArquivo = dfLocArquivo.fillna(0)


x = sns.scatterplot(
    x="Linhas de código de programação por arquivo", 
    y="Linhas de código de estilo por arquivo", 
    hue="Metodologia", 
    size="Arquivos de estilo",
    sizes=(60,600),
    alpha=0.7,
    data=dfLocArquivo
)

x.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)
x.set_xlim(-5,270)
x.set_ylim(-5,270)
# Out:
# (-5, 270)
